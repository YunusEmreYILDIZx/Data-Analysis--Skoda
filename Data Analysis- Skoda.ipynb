# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_excel("skoda.xlsx")

# %%
dataFrame.head()
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        Octavia  2017  10550       Manual    25250   Petrol  150  54.3
# 1         Citigo  2018   8200       Manual     1264   Petrol  145  67.3
# 2        Octavia  2019  15650    Automatic     6825   Diesel  145  67.3
# 3   Yeti Outdoor  2015  14000    Automatic    28431   Diesel  165  51.4
# 4         Superb  2019  18350       Manual    10912   Petrol  150  40.9
#
#             engineSize
# 0  2023-04-01 00:00:00
# 1                  1.0
# 2                  2.0
# 3                  2.0
# 4  2023-05-01 00:00:00

# %%
dataFrame.describe()
# Out:
#               year         price        mileage          tax
# count  6267.000000   6267.000000    6267.000000  6267.000000
# mean   2017.502314  14275.449338   20118.452050   117.407053
# std       1.734754   6332.051106   19955.410762    53.267949
# min    2004.000000    995.000000       5.000000     0.000000
# 25%    2017.000000   9495.000000    5812.500000   125.000000
# 50%    2018.000000  12998.000000   14653.000000   145.000000
# 75%    2019.000000  17990.000000   28000.000000   145.000000
# max    2020.000000  91874.000000  300000.000000   325.000000

# %%
dataFrame.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.distplot(dataFrame["price"])
# Out:
# C:\Users\emrey\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sbn.countplot(dataFrame["year"])
# Out:
# C:\Users\emrey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
dataFrame.corr()
# Out:
#              year     price   mileage       tax
# year     1.000000  0.606285 -0.724449  0.499762
# price    0.606285  1.000000 -0.480513  0.428709
# mileage -0.724449 -0.480513  1.000000 -0.412642
# tax      0.499762  0.428709 -0.412642  1.000000

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# mileage   -0.480513
# tax        0.428709
# year       0.606285
# price      1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x="mileage",y="price",data=dataFrame)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending = False).head(20)
# Out:
#         model  year  price transmission  mileage fuelType  tax    mpg  \
# 4993    Karoq  2019  91874    Automatic     3764   Petrol  145   40.9
# 4352   Superb  2019  39001    Semi-Auto     5000   Petrol  145   32.5
# 3330   Kodiaq  2020  38990    Automatic      493   Diesel  145   34.9
# 4560   Kodiaq  2020  37999    Automatic     5600   Diesel  150   34.9
# 6125   Kodiaq  2020  36999    Semi-Auto     1000   Diesel  145   39.2
# 2488   Kodiaq  2019  36995    Automatic     2261   Diesel  145   35.3
# 4807   Kodiaq  2020  36900    Automatic     3000   Diesel  150   38.7
# 4153   Kodiaq  2020  36750    Automatic     3678   Diesel  150   34.9
# 4346   Superb  2020  36000    Semi-Auto     6968   Hybrid  135  188.3
# 2115   Kodiaq  2020  35999    Automatic     1000   Diesel  150   39.2
# 1522   Kodiaq  2020  35990    Automatic     3500   Diesel  150   39.2
# 3979   Superb  2020  35990    Semi-Auto     5000   Hybrid  135  176.6
# 2944   Kodiaq  2019  35490    Automatic     1201   Diesel  145   38.7
# 2819   Kodiaq  2019  34995    Automatic     7303   Diesel  145   35.3
# 907    Kodiaq  2019  34995    Automatic     8966   Diesel  145   35.3
# 4702   Kodiaq  2020  34995    Automatic     6000   Diesel  150   39.2
# 4692   Kodiaq  2019  34995    Automatic     6000   Diesel  145   39.2
# 5551   Kodiaq  2020  34990    Automatic     3500   Diesel  145   39.2
# 4112   Kodiaq  2019  34950    Automatic     5189   Diesel  145   35.3
# 5724   Kodiaq  2019  34745    Automatic     4864   Diesel  145   37.2
#
#                engineSize
# 4993  2023-05-01 00:00:00
# 4352                  2.0
# 3330                  2.0
# 4560                  2.0
# 6125                  2.0
# 2488                  2.0
# 4807                  2.0
# 4153                  2.0
# 4346  2023-04-01 00:00:00
# 2115                  2.0
# 1522                  2.0
# 3979  2023-04-01 00:00:00
# 2944                  2.0
# 2819                  2.0
# 907                   2.0
# 4702                  2.0
# 4692                  2.0
# 5551                  2.0
# 4112                  2.0
# 5724                  2.0

# %%
dataFrame.sort_values("price",ascending = True).head(20)
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 5937      Fabia  2006    995       Manual   107765   Petrol  165  47.1
# 6069    Octavia  2010   1190       Manual   300000   Diesel  125  57.6
# 5970      Fabia  2010   1250       Manual   145268   Diesel   30  55.4
# 5878      Fabia  2006   1295       Manual   141000   Diesel  125  60.1
# 5441      Fabia  2006   1295       Manual   100964   Petrol  160  47.1
# 5532      Fabia  2004   1295       Manual    96000   Petrol  165  47.1
# 5585    Octavia  2010   1485       Manual   250650   Diesel  125  57.6
# 6149      Fabia  2009   1490       Manual    72464   Petrol  150  47.9
# 5235    Octavia  2005   1495       Manual   119017   Diesel  160  47.9
# 6134    Octavia  2008   1500       Manual   110265   Diesel  145  54.3
# 6035      Fabia  2007   1500       Manual    74000   Petrol  200  42.2
# 5210      Fabia  2008   1650       Manual   111034   Petrol  150  47.9
# 6103    Octavia  2008   1999       Manual   112600   Petrol  235  39.8
# 5809    Octavia  2007   2295       Manual   116000   Diesel  165  47.9
# 5695      Fabia  2009   2295       Manual   102645   Petrol  145  42.2
# 5749    Octavia  2008   2495       Manual   104273   Diesel  145  53.3
# 5626   Roomster  2009   2495       Manual    97000   Petrol  190  40.9
# 5780      Fabia  2012   2495       Manual   130000   Petrol  145  47.9
# 5750      Fabia  2010   2495       Manual   109575   Diesel   30  61.4
# 5751    Octavia  2009   2495       Manual   107038   Diesel  125  53.3
#
#                engineSize
# 5937  2023-02-01 00:00:00
# 6069  2023-09-01 00:00:00
# 5970  2023-04-01 00:00:00
# 5878  2023-04-01 00:00:00
# 5441  2023-02-01 00:00:00
# 5532  2023-02-01 00:00:00
# 5585  2023-09-01 00:00:00
# 6149  2023-02-01 00:00:00
# 5235                  2.0
# 6134  2023-09-01 00:00:00
# 6035  2023-04-01 00:00:00
# 5210  2023-02-01 00:00:00
# 6103  2023-04-01 00:00:00
# 5809                  2.0
# 5695  2023-02-01 00:00:00
# 5749  2023-09-01 00:00:00
# 5626  2023-04-01 00:00:00
# 5780  2023-04-01 00:00:00
# 5750  2023-09-01 00:00:00
# 5751  2023-09-01 00:00:00

# %%
len(dataFrame)
# Out:
# 6267

# %%
len(dataFrame) * 0.01
# Out:
# 62.67

# %%
yuzdeDoksanDokuzDf = dataFrame.sort_values("price",ascending = False).iloc[131:]

# %%
yuzdeDoksanDokuzDf.describe()
# Out:
#               year         price        mileage          tax
# count  6136.000000   6136.000000    6136.000000  6136.000000
# mean   2017.461701  13878.175847   20450.214472   116.814700
# std       1.728942   5721.888608   20028.495581    53.675302
# min    2004.000000    995.000000       5.000000     0.000000
# 25%    2017.000000   9478.750000    6000.000000   125.000000
# 50%    2018.000000  12991.000000   14944.000000   145.000000
# 75%    2019.000000  17495.000000   28317.000000   145.000000
# max    2020.000000  29990.000000  300000.000000   325.000000

# %%
plt.figure(figsize=(7,5))
sbn.distplot(yuzdeDoksanDokuzDf["price"])
# Out:
# C:\Users\emrey\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
dataFrame.describe()
# Out:
#               year         price        mileage          tax
# count  6267.000000   6267.000000    6267.000000  6267.000000
# mean   2017.502314  14275.449338   20118.452050   117.407053
# std       1.734754   6332.051106   19955.410762    53.267949
# min    2004.000000    995.000000       5.000000     0.000000
# 25%    2017.000000   9495.000000    5812.500000   125.000000
# 50%    2018.000000  12998.000000   14653.000000   145.000000
# 75%    2019.000000  17990.000000   28000.000000   145.000000
# max    2020.000000  91874.000000  300000.000000   325.000000

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 2004     1295.000000
# 2005     2093.000000
# 2006     1195.000000
# 2007     2571.250000
# 2008     2471.500000
# 2009     2470.000000
# 2010     3134.000000
# 2011     4579.714286
# 2012     5244.529412
# 2013     6572.795699
# 2014     7792.306011
# 2015     9131.178947
# 2016    10336.263095
# 2017    12012.348928
# 2018    14058.375286
# 2019    18401.019395
# 2020    22589.634058
# Name: price, dtype: float64

# %%
yuzdeDoksanDokuzDf.groupby("year").mean()["price"]
# Out:
# year
# 2004     1295.000000
# 2005     2093.000000
# 2006     1195.000000
# 2007     2571.250000
# 2008     2471.500000
# 2009     2470.000000
# 2010     3134.000000
# 2011     4579.714286
# 2012     5244.529412
# 2013     6572.795699
# 2014     7792.306011
# 2015     9131.178947
# 2016    10336.263095
# 2017    12012.348928
# 2018    14037.880871
# 2019    17856.984298
# 2020    20117.819820
# Name: price, dtype: float64

# %%
dataFrame[dataFrame.year != 1970].groupby("year").mean()["price"]
# Out:
# year
# 2004     1295.000000
# 2005     2093.000000
# 2006     1195.000000
# 2007     2571.250000
# 2008     2471.500000
# 2009     2470.000000
# 2010     3134.000000
# 2011     4579.714286
# 2012     5244.529412
# 2013     6572.795699
# 2014     7792.306011
# 2015     9131.178947
# 2016    10336.263095
# 2017    12012.348928
# 2018    14058.375286
# 2019    18401.019395
# 2020    22589.634058
# Name: price, dtype: float64

# %%
dataFrame = yuzdeDoksanDokuzDf

# %%
dataFrame.describe()
# Out:
#               year         price        mileage          tax
# count  6136.000000   6136.000000    6136.000000  6136.000000
# mean   2017.461701  13878.175847   20450.214472   116.814700
# std       1.728942   5721.888608   20028.495581    53.675302
# min    2004.000000    995.000000       5.000000     0.000000
# 25%    2017.000000   9478.750000    6000.000000   125.000000
# 50%    2018.000000  12991.000000   14944.000000   145.000000
# 75%    2019.000000  17495.000000   28317.000000   145.000000
# max    2020.000000  29990.000000  300000.000000   325.000000

# %%
dataFrame = dataFrame[dataFrame.year != 1970]

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 2004     1295.000000
# 2005     2093.000000
# 2006     1195.000000
# 2007     2571.250000
# 2008     2471.500000
# 2009     2470.000000
# 2010     3134.000000
# 2011     4579.714286
# 2012     5244.529412
# 2013     6572.795699
# 2014     7792.306011
# 2015     9131.178947
# 2016    10336.263095
# 2017    12012.348928
# 2018    14037.880871
# 2019    17856.984298
# 2020    20117.819820
# Name: price, dtype: float64

# %%
dataFrame.head()
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 996    Superb  2019  29990    Semi-Auto     4580   Petrol  145  33.2
# 4419   Kodiaq  2019  29990    Automatic     2435   Petrol  150  31.4
# 4268   Kodiaq  2019  29990    Automatic     5475   Petrol  150  31.4
# 5263   Kodiaq  2019  29990    Automatic     3021   Diesel  145  37.2
# 3005   Kodiaq  2019  29990    Automatic     4615   Petrol  145  31.4
#
#      engineSize
# 996         2.0
# 4419        2.0
# 4268        2.0
# 5263        2.0
# 3005        2.0
